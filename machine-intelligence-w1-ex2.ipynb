# %% [markdown]
# ## Multipercepton
#
# ### 1

# %%
# 2)


import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error as MSE

# %%
NO_MLPS = 50
NO_HIDDEN_LAYERS=10

W = 1*np.random.randn(NO_MLPS,NO_HIDDEN_LAYERS) + 0 # avg = 0 sigma = 1
B = 4*np.random.uniform(-2,2,(NO_MLPS,NO_HIDDEN_LAYERS)) - 2 # adj range from (0,1) to 

print( "Shape W : " + str(W.shape) )
print( "Shape A : " + str(A.shape) )
print( "Shape B : " + str(B.shape) )

NO_X = 100
X = np.random.uniform(-2,2, NO_X)
X.sort()
print("Numbers of X : %d " % len(X) )
print(X)
# Out:
# Shape W : (50, 10)
# Shape A : (50, 10)
# Shape B : (50, 10)
# Numbers of X : 100
# [-1.96602324 -1.92936729 -1.90535974 -1.80866057 -1.75140366 -1.74807345
#  -1.73957108 -1.71750418 -1.62558832 -1.62109383 -1.60769277 -1.56579757
#  -1.49107195 -1.48779224 -1.48014506 -1.46819411 -1.39295098 -1.3627118
#  -1.34488169 -1.34395516 -1.28661803 -1.13168692 -1.08745188 -1.07997657
#  -1.07347666 -1.05559977 -0.99832026 -0.92150435 -0.89071941 -0.88905356
#  -0.81026505 -0.76664579 -0.74910015 -0.74192427 -0.73958268 -0.73175611
#  -0.72089667 -0.71901518 -0.64575077 -0.6429837  -0.63737134 -0.58086684
#  -0.5046103  -0.47914295 -0.4595456  -0.4436711  -0.40581402 -0.31672436
#  -0.29567723 -0.2377738  -0.21858138 -0.19964378 -0.16652397 -0.14896447
#   0.01212676  0.05078303  0.05505247  0.10748784  0.14165083  0.14859598
#   0.16284414  0.2326426   0.29881323  0.30159208  0.34598528  0.46972565
#   0.50271045  0.52919807  0.58460733  0.6317357   0.68104632  0.69103952
#   0.76375676  0.79000723  0.80116186  0.91289092  0.95498734  1.084232
#   1.1465438   1.16418529  1.26597106  1.31816256  1.3506478   1.35423451
#   1.3650973   1.37811298  1.39712932  1.52495306  1.56767034  1.57689928
#   1.59007819  1.59546247  1.60405044  1.76294417  1.77872008  1.88441336
#   1.90156317  1.90772404  1.97868745  1.99102352]

# %%
def pred_Y( w, a, b):
    Y = [ np.dot(w, np.tanh(a*(x-b)).T ) for x in X ]
    return Y

def pred_and_plot(A):
    Y_mlps = [ pred_Y(W[i], A[i], B[i]) for i in range(NO_MLPS) ]

    plt.xlabel('X')
    plt.ylabel('Y')

    for i in range(NO_MLPS):
        plt.plot(X, Y_mlps[i])
    return Y_mlps

A_2 = 2*np.random.randn(NO_MLPS,NO_HIDDEN_LAYERS) + 0
Y_A_2 = pred_and_plot(A_2)

# %%
A_05 = 0.5*np.random.randn(NO_MLPS,NO_HIDDEN_LAYERS) + 0
Y_A_05 = pred_and_plot(A_05)

# %%
G_X = -X

mse_Y_A_2 = [ MSE(G_X, y) for y in Y_A_2 ]
mse_Y_A_05 = [ MSE(G_X, y) for y in Y_A_05 ]

print("Average MSE for a ~ N(0,2) : %2.4f" % np.avg(mse_Y_A_2) )
print("Average MSE for a ~ N(0,0.5) : %2.4f" % np.avg(mse_Y_A_05) )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-24abf22efd9f> in <module>()
#       4 mse_Y_A_05 = [ MSE(G_X, y) for y in Y_A_05 ]
#       5
# ----> 6 print("Average MSE for a ~ N(0,2) : %2.4f" % np.avg(mse_Y_A_2) )
#       7 print("Average MSE for a ~ N(0,0.5) : %2.4f" % np.avg(mse_Y_A_05) )
#
# AttributeError: module 'numpy' has no attribute 'avg'
